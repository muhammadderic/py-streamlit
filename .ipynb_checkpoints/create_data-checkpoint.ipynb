# %%
import streamlit as st
from supabase import create_client, Client

url = "https://mmvvmvvclbwbwobnabiv.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Im1tdnZtdnZjbGJ3YndvYm5hYml2Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MzA2MzQ1NTQsImV4cCI6MjA0NjIxMDU1NH0.EsAjVTooROtlB9Zzyya6iNDiP7gtTyDXQYxF8sef6KY"

supabase: Client = create_client(url, key)

# %%
datalist = supabase.table("people").select("*").eq('name', 'deric').execute().data
datalist
# Out:
# 2024-11-25 11:55:33.516 INFO    httpx: HTTP Request: GET https://mmvvmvvclbwbwobnabiv.supabase.co/rest/v1/people?select=%2A&name=eq.deric "HTTP/2 200 OK"
# [{'id': 1,
#   'created_at': '2024-11-25T04:46:30.367009+00:00',
#   'name': 'deric',
#   'age': 23}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['No', 'Name', 'Age'])

# %%
for i in range(0, len(datalist)):
    currentItem = datalist[i]
    df.loc[i] = [datalist[i]['id'], datalist[i]['name'], datalist[i]['age']]

# %%
df
# Out:
#    No   Name  Age
# 0   1  deric   23
